# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
Prostate_canser = pd.read_csv('Prostate_Cancer_Preprocessed_1.csv')## Reading csv file and convert to data frame
Prostate_canser
# Out:
#    diagnosis_result  radius  texture  perimeter    area  smoothness  \
# 0                 M      23       12      151.0   954.0     0.10273
# 1                 B       9       13      133.0  1326.0     0.10273
# 2                 M      21       27      130.0  1203.0     0.12500
# 3                 M      14       16       78.0   386.0     0.07000
# 4                 M       9       19      135.0  1297.0     0.10273
# ..              ...     ...      ...        ...     ...         ...
# 95                M      23       16      132.0  1264.0     0.09100
# 96                B      22       14       78.0   451.0     0.10500
# 97                B      19       27       62.0   295.0     0.10200
# 98                B      21       24       74.0   413.0     0.09000
# 99                M      16       27       94.0   643.0     0.09800
#
#     compactness  symmetry  fractal_dimension
# 0        0.1267     0.242            0.07900
# 1        0.0790     0.181            0.05700
# 2        0.1600     0.207            0.06000
# 3        0.1267     0.260            0.06469
# 4        0.1330     0.181            0.05900
# ..          ...       ...                ...
# 95       0.1310     0.210            0.05600
# 96       0.0710     0.190            0.06600
# 97       0.0530     0.135            0.06900
# 98       0.0750     0.162            0.06600
# 99       0.1140     0.188            0.06400
#
# [100 rows x 9 columns]

# %%
Prostate_canser.describe()
# Out:
#            radius     texture   perimeter         area  smoothness  \
# count  100.000000  100.000000  100.000000   100.000000  100.000000
# mean    16.850000   18.230000   96.027800   691.128800    0.101542
# std      4.879094    5.192954   22.423953   296.861946    0.012861
# min      9.000000   11.000000   52.000000   202.000000    0.070000
# 25%     12.000000   14.000000   82.500000   476.750000    0.093500
# 50%     17.000000   17.500000   94.000000   644.000000    0.102000
# 75%     21.000000   22.250000  113.250000   907.000000    0.110000
# max     25.000000   27.000000  151.000000  1404.000000    0.129000
#
#        compactness    symmetry  fractal_dimension
# count   100.000000  100.000000         100.000000
# mean      0.121431    0.190275           0.064114
# std       0.052421    0.025544           0.007006
# min       0.038000    0.135000           0.053000
# 25%       0.080500    0.172000           0.059000
# 50%       0.118500    0.190000           0.063000
# 75%       0.153250    0.207250           0.069000
# max       0.267000    0.260000           0.082000

# %%
Prostate_canser.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   diagnosis_result   100 non-null    object
#  1   radius             100 non-null    int64
#  2   texture            100 non-null    int64
#  3   perimeter          100 non-null    float64
#  4   area               100 non-null    float64
#  5   smoothness         100 non-null    float64
#  6   compactness        100 non-null    float64
#  7   symmetry           100 non-null    float64
#  8   fractal_dimension  100 non-null    float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 7.2+ KB

# %%
x_train = Prostate_canser.drop("diagnosis_result",axis=1)
x_train.drop(x_train.tail(30).index,inplace = True)
x_train=x_train.values        

print(x_train.shape)
# len(x_train)
# Out:
# (70, 8)

# %%
y_train =Prostate_canser["diagnosis_result"] # to make lables without inputs in array
y_test = y_train.tail(30).values
y_train = y_train.map({'M':0 , 'B':1})
y_train.drop(y_train.tail(30).index,inplace = True)
y_train = y_train.values

        
y= y_train.reshape(len(y_train),1)
print(len(y))
print(y_test.shape)
# Out:
# 70
# (30,)

# %%
def distance_ecq(x_traain,x_test_point):
    distances=[]
    for row in range(len(x_traain)) : #loop over rows in x_train
        current_train_piont = x_traain[row]
        # print(current_train_piont.shape)
        current_distance = 0    #initalize distance zero
        # for eacr_row
        for column in range(len(current_train_piont)): # loop over columns(feature) in each row of x_train
            current_distance += (current_train_piont[column]-x_test_point[column])**2
        # current_distance = np.subtract(current_train_piont,x_test_point)
        # acummalation = np.sum(np.square(current_distance)) 
        current_distance=np.sqrt(current_distance)
        # print(x_test_point.shape)
        distances.append(current_distance)
    # distances = pd.DataFrame(data=distances, columns=["dist"])
    return distances

# %%
def nearest_neighbour(distance_point,k):
    # distance point: distance between test point and each ponit in tranining 
    # k : number of neighbours to consider for prediction
    nearest_neighbors_indices = np.argsort(distance_point)[:k]  ##index prediction
    # print(nearest_neighbors_indices)        
    return nearest_neighbors_indices

# %%
def voting (df_nearst , y_traain):
    nearest_neighbors_classes = y_traain[df_nearst]         ## prediction of index from past function
    X_flattened = nearest_neighbors_classes.flatten() ## convert from 2 dimension to 1 dimension
    # print(nearest_neighbors_classes)
    # print(X_flattened)
    prediction = np.argmax(np.bincount(X_flattened))  ## ygeeb aktr 7aga etkrrt
    # print(prediction)
    return prediction

# %%
x_test = Prostate_canser.tail(30).drop("diagnosis_result",axis=1).values #choose data to using in test
x_test.shape
# Out:
# (30, 8)

# %%
def predict(predict_num):
    predict_string = []
    for i in predict_num:
        if i == 1:
            predict_string.append("B")
        else:
            predict_string.append("M")
    return predict_string

# %%
def knn_from_scratch(x_train , y_train ,x_test , k):
    y_pred = []
    for x_test_point in x_test:
        distance_point = distance_ecq(x_train,x_test_point)
        df_nearst_point = nearest_neighbour(distance_point, k)
        y_pred_point = voting(df_nearst_point,y_train)
        y_pred.append(y_pred_point)
        predict_string = predict(y_pred)

    return predict_string

# %%
from sklearn.metrics import accuracy_score

# %%
# Fit the model with many K values
scores = []
max_score = 0
best_K = 0
for i in range(10):    
    y_pred_scratch = knn_from_scratch(x_train,y,x_test,i+1)
    accuracy = accuracy_score(y_test, y_pred_scratch)
    if accuracy > max_score:
        max_score = accuracy
        best_K = i+1
    
    scores.append( [i+1, round(accuracy*100,2)] )

# %%
print("Accuracy obtained by KNN models: ",scores)
print("Best K: ", best_K)
print("Best Accuracy: ", round(max_score*100,2))
# Out:
# Accuracy obtained by KNN models:  [[1, 63.33], [2, 66.67], [3, 83.33], [4, 73.33], [5, 83.33], [6, 73.33], [7, 83.33], [8, 76.67], [9, 80.0], [10, 76.67]]
# Best K:  3
# Best Accuracy:  83.33
